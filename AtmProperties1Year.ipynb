# %% [markdown]
# # Scan OHP sky properties during one year
#
# - Author :Sylvie Dagoret-Campagne
# - affiliation : LAL,IN2P3,CNRS
# - organization : LSST
#
# - creation : September 22th 2016

# %%
# Set up matplotlib and use a nicer set of plot parameters
# %config InlineBackend.rc = {}
import matplotlib
import matplotlib as mpl
matplotlib.rc_file("templates/matplotlibrc")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
import numpy as np
from mpl_toolkits.basemap import Basemap
from matplotlib import colors
from matplotlib.backends.backend_pdf import PdfPages
import pandas as pd
import h5py

from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import libCaliopAOD as cal

# %%
#from __future__ import print_function
import datetime
from matplotlib.dates import MonthLocator, WeekdayLocator,DateFormatter
from matplotlib.dates import MONDAY

# %%
year_number=2016   # choose the month number
month_start=0      # choose first month
month_stop=7      # choose last month
month_numbers=np.arange(month_start,month_stop+1)
month_stringnumber=['01','02','03','04','05','06','07','08','09','10','11','12']
month_name=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
number_of_monthes=month_numbers.shape[0]

# %%
dates= [datetime.date(year_number, m, 1) for m in range(month_start+1,month_stop+2)]

# %%
path_root='/Users/dagoret-campagnesylvie/MacOsX/LSST/MyWork/GitHub/CALIPSODATA2016/CAL_LID_L3_APro_AllSky-Standard-V3-00'

# %%
filename_base='CAL_LID_L3_APro_AllSky-Standard-V3-00'

# %%
month_name
# Out:
# ['Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Sep',
#  'Oct',
#  'Nov',
#  'Dec']

# %%
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(1,1,1)

for imonth in month_numbers:
    
    if imonth == 1:
        continue
        
    dayfile_fullname=cal.GetL3FilenameDay(path_root,filename_base,year_number,imonth)
    nightfile_fullname=cal.GetL3FilenameNight(path_root,filename_base,year_number,imonth)
    temperatures=cal.GetL3Value(dayfile_fullname,'Temperature_Mean')
    pressures=cal.GetL3Value(dayfile_fullname,'Pressure_Mean')
    humidity=cal.GetL3Value(dayfile_fullname,'Relative_Humidity_Mean')
    altitudes=cal.GetL3APAltitudes()
    
    month_str= '%02d' %(imonth+1)
    ax.plot(temperatures,altitudes,'-',label=month_name[imonth],lw=2)
    
title= "Temperature profile at OHP site in year %d" %year_number
figfilename="OHPMonthlyTemperatureProfilesY%d.pdf" %year_number
ax.set_ylabel('altitudes (km)')
ax.set_xlabel('Temperature ($^o$C)')
ax.grid(True)
plt.xlim((-60,30))
plt.legend()
plt.title(title)  
plt.legend(loc='best')
plt.savefig(figfilename, bbox_inches='tight')

# %%
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(1,1,1)

for imonth in month_numbers:
    
    if imonth == 1:
        continue
    
    dayfile_fullname=cal.GetL3FilenameDay(path_root,filename_base,year_number,imonth)
    nightfile_fullname=cal.GetL3FilenameNight(path_root,filename_base,year_number,imonth)
    temperatures=cal.GetL3Value(dayfile_fullname,'Temperature_Mean')
    pressures=cal.GetL3Value(dayfile_fullname,'Pressure_Mean')
    humidity=cal.GetL3Value(dayfile_fullname,'Relative_Humidity_Mean')
    altitudes=cal.GetL3APAltitudes()
    
    month_str= '%02d' %(imonth+1)
    ax.plot(pressures,altitudes,'-',label=month_name[imonth],lw=2)
    
title= "Pressure profile at OHP site in year %d" %year_number
figfilename="OHPMonthlyPressureProfilesY%d.pdf" %year_number
ax.set_ylabel('altitudes (km)')
ax.set_xlabel('Pressure')
ax.grid(True)
plt.xlim((200,1100))
plt.legend()
plt.title(title)    
plt.legend(loc='best')
plt.savefig(figfilename, bbox_inches='tight')

# %%
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(1,1,1)

for imonth in month_numbers:
    
    if imonth == 1:
        continue
    
    dayfile_fullname=cal.GetL3FilenameDay(path_root,filename_base,year_number,imonth)
    nightfile_fullname=cal.GetL3FilenameNight(path_root,filename_base,year_number,imonth)
    temperatures=cal.GetL3Value(dayfile_fullname,'Temperature_Mean')
    pressures=cal.GetL3Value(dayfile_fullname,'Pressure_Mean')
    humidity=cal.GetL3Value(dayfile_fullname,'Relative_Humidity_Mean')
    altitudes=cal.GetL3APAltitudes()
    
    month_str= '%02d' %(imonth+1)
    ax.plot(humidity,altitudes,'-',label=month_name[imonth],lw=2)
    
title= "humidity profile at OHP site in year %d" %year_number
figfilename="OHPMonthlyHumidityProfilesY%d.pdf" %year_number
ax.set_ylabel('altitudes (km)')
ax.set_xlabel('humidity')
ax.grid(True)
#plt.xlim((0,100))
plt.legend()
plt.title(title)  
plt.legend(loc='best')
plt.savefig(figfilename, bbox_inches='tight')
